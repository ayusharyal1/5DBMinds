# %%
# This program uses scikits gridsearch cv and helps to find the best set of parameters for a classifier. This is 
# generally used for tuning up the classifier paramters.

# %%
import pandas as pd
import numpy as np
import string as str
from os import listdir
from os.path import isfile, join
from  datetime import datetime
from os import listdir
from os.path import isfile, join

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import nltk.stem
from sklearn.decomposition import PCA

from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import classification_report
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.cross_validation import KFold

import plotly.plotly as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt
# %matplotlib inline  
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfTransformer
import AppVectorizerModule as ATV

from sklearn.decomposition import PCA

# %%
# Make a gridsearchresult folder
resultpath='/home/ayush/Desktop/gsresult/'
#resultpath='../gsresult/'

# %%
# A function to return parameters based on classifier
def getParamGrid(clfname):
    clfname=getClassifierName(clfname)
    param_grid={}
    if clfname=='RandomForestClassifier':   
        param_grid = { 
            'n_estimators': [50,100,200,500],
            'max_features': [None, 'sqrt', 'log2'],
            'criterion' : ['gini','entropy'],
            'oob_score' : [True,False],
            'random_state' : [0,10,20,30]
        }
    elif clfname=='DecisionTreeClassifier':
        param_grid = { 
            'max_features': ['auto', 'sqrt', 'log2'],
            'criterion' : ['gini','entropy'],
            'random_state' : [0,10,20,30],
            'splitter' : ['random','best']
        }
    elif clfname=='LinearSVC':
        param_grid = { 
            'tol' : [0.0001,0.0002,0.0003,0.004],
            'multi_class' : ['ovr','crammer_singer'],
            'fit_intercept' : [True,False],
            'random_state': [0,10,20,30],
            'max_iter' : [1000,1500],
            'C':[1.0,10.0,100.0]
        }
    elif clfname=='LogisticRegression':
          param_grid = { 
            'random_state': [0,10,20,30],
            'max_iter' : [1000,1500],
            'multi_class' : ['ovr'],
            'tol' : [0.0001,0.0002,0.0003,0.004],
            'solver' : ['newton-cg', 'lbfgs', 'liblinear'],
            'fit_intercept' : [True,False],
            'C':[1.0,10.0,100.0]
        }
    elif clfname=='SGDClassifier':
        param_grid = { 
           'alpha':[0.0001,0.0002,0.0005,0.001,0.002],
            'fit_intercept' : [True,False],
            'n_iter' : [5,10,20,50],
            'shuffle' : [True,False],
            'random_state': [0,10,20,30],
            'warm_start':[True,False]
        }
    elif clfname=='RidgeClassifier':
        param_grid = { 
            'alpha':[0.0001,0.0002,0.0005,0.001,0.002],
            'copy_X':[True,False],
            'fit_intercept' : [True,False],
            'max_iter' : [500,1000],
            'normalize' : [True,False],
            'solver': ['auto', 'svd', 'cholesky','lsqr','sparse_cg'],
            'tol' : [0.0001,0.0002,0.0003,0.0004],
        }
    elif clfname=='KNeighborsClassifier':
        param_grid = { 
            'n_neighbors':[5,10,15,20],
            'weights':['uniform','distance'],
            'algorithm' : ['auto','ball_tree', 'kd_tree','brute'],
            'metric':['euclidean','manhattan','chebyshev','minkowski']
        }
    return param_grid

def getClassifierName(clf):
    if type(clf).__name__ != 'OneVsRestClassifier':
        #print type(clf).__name__
        return type(clf).__name__
    else:
        #print type(clf.estimator).__name__ 
        return type(clf.estimator).__name__

# %%
#A function to printResults
def printResults(resultpath,clfname,grid_scores,best_params,clf_report,best_score):
    print resultpath+clfname
    gridResults=open(resultpath+'_Result_'+clfname+'.txt', 'w')
    print "Grid Scores:\n"
    gridResults.write("Grid Scores:\n")
    for params, mean_score, scores in grid_scores:
            print("%0.3f (+/-%0.03f) for %r"% (mean_score, scores.std() * 2, params))
            gridResults.write("\n%0.3f (+/-%0.03f) for %r"% (mean_score, scores.std() * 2, params))
    print "\nBest Score:\n"
    gridResults.write("\nBest Score:\n")
    print "\nBest Params:\n"
    gridResults.write("\nBest Params:\n")
    print best_score
    gridResults.write("%s"%(best_score))
    print best_params
    gridResults.write("%s"%(best_params))
    print "\nClassification Report:\n"
    gridResults.write("\nClassification Report:\n")
    print(clf_report)
    gridResults.write("%s"%(clf_report))

# %%
#single file
path='/home/ayush/Desktop/BigData_ProjectData/PlayStoreCsv/data/big_data1.csv'
df= pd.read_csv(path,sep=',',header=0)

#whole data
'''dfs=[]
path='../data/'
onlyfiles = [ f for f in listdir(path) if isfile(join(path,f)) and f.endswith( 'csv' ) ]
print onlyfiles
for eachFile in onlyfiles:
    path1='../data/'+eachFile
    df1= pd.read_csv(path1,sep=',',header=0)
    print df1.shape[0]
    dfs.append(df1)
df=pd.concat(dfs)
df.shape[0]'''
# Out:
# "dfs=[]\npath='../data/'\nonlyfiles = [ f for f in listdir(path) if isfile(join(path,f)) and f.endswith( 'csv' ) ]\nprint onlyfiles\nfor eachFile in onlyfiles:\n    path1='../data/'+eachFile\n    df1= pd.read_csv(path1,sep=',',header=0)\n    print df1.shape[0]\n    dfs.append(df1)\ndf=pd.concat(dfs)\ndf.shape[0]"

# %%
def mapBooleanColumns(x):
    if x==True:
        return 1
    else:
        return 0
    
def mappingScores(x):
    if x>0 and x<=1:
        return 1
    elif x>1 and x<=2:
        return 2
    elif x>2 and x<=3:
        return 3
    elif x>3 and x<=4:
        return 4
    else:
        return 5

def mapDates(d):
    d=d[:10]
    d1= datetime.now()
    d2=datetime.strptime(d, "%Y-%m-%d")
    return (d1.year - d2.year)*12 + d1.month - d2.month    
    
def seperateInstallations(col_name):
    return_data_type_as=None
    ls = col_name.str.split('-').str.get(0).str.strip(' ').str.replace(',','') #series object
    hs = col_name.str.split('-').str.get(1).str.strip(' ').str.replace(',','') #series object
    ls = ls.astype(float).fillna(0.0)
    hs = hs.astype(float).fillna(0.0)
    return ls, hs

def processAppSize(x):
    if x==-1:
        return 0.5
    else:
        return x

# %%
# Transforming the data into numerical forms
df.IsTopDeveloper=map(mapBooleanColumns,df.IsTopDeveloper)
df.HaveInAppPurchases=map(mapBooleanColumns,df.HaveInAppPurchases)
df.IsFree=map(mapBooleanColumns,df.IsFree)
df.Score=map(mappingScores,df.Score)
df.PublicationDate=map(mapDates,df.PublicationDate)
df.LastUpdateDate=map(mapDates,df.LastUpdateDate)
df['minInstall'],df['maxInstall']=seperateInstallations(df.Instalations)
df.AppSize=map(processAppSize,df.AppSize)

# %%
# Selecting Features
df=df.head(n=3000)
X=df[['Price','PublicationDate','AppSize','LastUpdateDate','IsFree','HaveInAppPurchases','minInstall','maxInstall']]
y=pd.DataFrame(df[['Score']])

# %%
# Vectorising the features and merging them to selected numerical features     
min_df=1
max_df=0.9
lowercase=True
stem_vectorizer = ATV.StemmedCountVectorizer(encoding='utf-8',
                                         min_df =min_df,
                                         max_df =max_df,
                                         stop_words='english',
                                         analyzer='word',
                                         lowercase = lowercase)
                
##set filterparameter to your vectorizer
filter_by=["OnlyEng", "AllLang"] #two options are available
count_dialect = True 
n_samples = df.shape[0] #as u choose it.
stem_vectorizer.setfilter_option(filter_by[1],count_dialect)    
# Vectorizing the Category Column
nCategory, fmatrix, column_vectorizer = ATV.vectorize_columnTfIdf(df, 'Category', stem_vectorizer,df.shape[0],True)
# Vectorizing the Name Column
stem_vectorizer.setfilter_option(filter_by[0],count_dialect) 
nName, fmatrix1, column_vectorizer1 = ATV.vectorize_columnTfIdf(df, 'Name', stem_vectorizer,df.shape[0],True)
# Vectorizing the Description Column
nDescription, fmatrix2, column_vectorizer2 = ATV.vectorize_columnTfIdf(df, 'Description',stem_vectorizer,df.shape[0],True)
# Vectorizing the Content Rating Column
nContentRating, fmatrix3, column_vectorizer3 = ATV.vectorize_columnTfIdf(df, 'ContentRating',stem_vectorizer,df.shape[0],True)
# Vectorizing the Developer Column
nDeveloper, fmatrix3, column_vectorizer3 = ATV.vectorize_columnTfIdf(df, 'Developer',stem_vectorizer,df.shape[0],True)

finaldf = pd.concat([X,nCategory,nName,nDescription,nContentRating,nDeveloper],axis=1)
# Out:
# formed dataframe of size:( 3000 , 41 )
# formed dataframe of size:( 3000 , 1261 )
# formed dataframe of size:( 3000 , 7635 )
# formed dataframe of size:( 3000 , 7 )
# formed dataframe of size:( 3000 , 602 )

# %%
print finaldf.shape,y.shape
# Out:
# (3000, 9554) (3000, 1)

# %%
def processClassifier(Xtrain,Xtest,ytrain,ytest,cl,param_grid,resultpath):
    clf = GridSearchCV(estimator=cl, param_grid=param_grid,n_jobs=4,cv=10)
    clf.fit(Xtrain, ytrain)
    ypred=clf.predict(Xtest)

    grid_scores=clf.grid_scores_
    best_params=clf.best_params_
    clf_report=classification_report(ytest,ypred)
    best_score=clf.best_score_
    printResults(resultpath,getClassifierName(cl),grid_scores,best_params,clf_report,best_score)

# %%
classifiers = [RandomForestClassifier(),LogisticRegression(),SGDClassifier(),RidgeClassifier()
              ,DecisionTreeClassifier(),KNeighborsClassifier()]

xx=finaldf.copy()
pca = PCA(n_components=100)
xx= pca.fit_transform(xx)
yy=y.values
Xtrain, Xtest, ytrain, ytest = train_test_split(xx, yy.ravel(), test_size=0.7, random_state=0)
for clf in classifiers:
    print ("\n>> Start Processing %s"%(getClassifierName(clf)))
    param_grid=getParamGrid(clf)
    processClassifier(Xtrain,Xtest,ytrain,ytest,clf,param_grid,resultpath)
    print ("\n>> End Processing %s"%(getClassifierName(clf)))
# Out:
# >> Start Processing RandomForestClassifier
# /home/ayush/Desktop/gsresult/RandomForestClassifier
# Grid Scores:
#
# 0.679 (+/-0.071) for {'max_features': None, 'n_estimators': 50, 'oob_score': True, 'random_state': 0, 'criterion': 'gini'}
# 0.671 (+/-0.117) for {'max_features': None, 'n_estimators': 50, 'oob_score': True, 'random_state': 10, 'criterion': 'gini'}
# 0.668 (+/-0.100) for {'max_features': None, 'n_estimators': 50, 'oob_score': True, 'random_state': 20, 'criterion': 'gini'}
# 0.663 (+/-0.079) for {'max_features': None, 'n_estimators': 50, 'oob_score': True, 'random_state': 30, 'criterion': 'gini'}
# 0.679 (+/-0.071) for {'max_features': None, 'n_estimators': 50, 'oob_score': False, 'random_state': 0, 'criterion': 'gini'}
# 0.671 (+/-0.117) for {'max_features': None, 'n_estimators': 50, 'oob_score': False, 'random_state': 10, 'criterion': 'gini'}
# 0.668 (+/-0.100) for {'max_features': None, 'n_estimators': 50, 'oob_score': False, 'random_state': 20, 'criterion': 'gini'}
# 0.663 (+/-0.079) for {'max_features': None, 'n_estimators': 50, 'oob_score': False, 'random_state': 30, 'criterion': 'gini'}
# 0.682 (+/-0.094) for {'max_features': None, 'n_estimators': 100, 'oob_score': True, 'random_state': 0, 'criterion': 'gini'}
# 0.664 (+/-0.120) for {'max_features': None, 'n_estimators': 100, 'oob_score': True, 'random_state': 10, 'criterion': 'gini'}
# 0.673 (+/-0.083) for {'max_features': None, 'n_estimators': 100, 'oob_score': True, 'random_state': 20, 'criterion': 'gini'}
# 0.668 (+/-0.086) for {'max_features': None, 'n_estimators': 100, 'oob_score': True, 'random_state': 30, 'criterion': 'gini'}
# 0.682 (+/-0.094) for {'max_features': None, 'n_estimators': 100, 'oob_score': False, 'random_state': 0, 'criterion': 'gini'}
# 0.664 (+/-0.120) for {'max_features': None, 'n_estimators': 100, 'oob_score': False, 'random_state': 10, 'criterion': 'gini'}
# 0.673 (+/-0.083) for {'max_features': None, 'n_estimators': 100, 'oob_score': False, 'random_state': 20, 'criterion': 'gini'}
# 0.668 (+/-0.086) for {'max_features': None, 'n_estimators': 100, 'oob_score': False, 'random_state': 30, 'criterion': 'gini'}
# 0.663 (+/-0.096) for {'max_features': None, 'n_estimators': 200, 'oob_score': True, 'random_state': 0, 'criterion': 'gini'}
# 0.674 (+/-0.094) for {'max_features': None, 'n_estimators': 200, 'oob_score': True, 'random_state': 10, 'criterion': 'gini'}
# 0.680 (+/-0.081) for {'max_features': None, 'n_estimators': 200, 'oob_score': True, 'random_state': 20, 'criterion': 'gini'}
# 0.672 (+/-0.105) for {'max_features': None, 'n_estimators': 200, 'oob_score': True, 'random_state': 30, 'criterion': 'gini'}
# 0.663 (+/-0.096) for {'max_features': None, 'n_estimators': 200, 'oob_score': False, 'random_state': 0, 'criterion': 'gini'}
# 0.674 (+/-0.094) for {'max_features': None, 'n_estimators': 200, 'oob_score': False, 'random_state': 10, 'criterion': 'gini'}
# 0.680 (+/-0.081) for {'max_features': None, 'n_estimators': 200, 'oob_score': False, 'random_state': 20, 'criterion': 'gini'}
# 0.672 (+/-0.105) for {'max_features': None, 'n_estimators': 200, 'oob_score': False, 'random_state': 30, 'criterion': 'gini'}
# 0.674 (+/-0.088) for {'max_features': None, 'n_estimators': 500, 'oob_score': True, 'random_state': 0, 'criterion': 'gini'}
# 0.674 (+/-0.099) for {'max_features': None, 'n_estimators': 500, 'oob_score': True, 'random_state': 10, 'criterion': 'gini'}
# 0.679 (+/-0.111) for {'max_features': None, 'n_estimators': 500, 'oob_score': True, 'random_state': 20, 'criterion': 'gini'}
# 0.681 (+/-0.100) for {'max_features': None, 'n_estimators': 500, 'oob_score': True, 'random_state': 30, 'criterion': 'gini'}
# 0.674 (+/-0.088) for {'max_features': None, 'n_estimators': 500, 'oob_score': False, 'random_state': 0, 'criterion': 'gini'}
# 0.674 (+/-0.099) for {'max_features': None, 'n_estimators': 500, 'oob_score': False, 'random_state': 10, 'criterion': 'gini'}
# 0.679 (+/-0.111) for {'max_features': None, 'n_estimators': 500, 'oob_score': False, 'random_state': 20, 'criterion': 'gini'}
# 0.681 (+/-0.100) for {'max_features': None, 'n_estimators': 500, 'oob_score': False, 'random_state': 30, 'criterion': 'gini'}
# 0.678 (+/-0.073) for {'max_features': 'sqrt', 'n_estimators': 50, 'oob_score': True, 'random_state': 0, 'criterion': 'gini'}
# 0.666 (+/-0.103) for {'max_features': 'sqrt', 'n_estimators': 50, 'oob_score': True, 'random_state': 10, 'criterion': 'gini'}
# 0.671 (+/-0.071) for {'max_features': 'sqrt', 'n_estimators': 50, 'oob_score': True, 'random_state': 20, 'criterion': 'gini'}
# 0.678 (+/-0.086) for {'max_features': 'sqrt', 'n_estimators': 50, 'oob_score': True, 'random_state': 30, 'criterion': 'gini'}
# 0.678 (+/-0.073) for {'max_features': 'sqrt', 'n_estimators': 50, 'oob_score': False, 'random_state': 0, 'criterion': 'gini'}
# 0.666 (+/-0.103) for {'max_features': 'sqrt', 'n_estimators': 50, 'oob_score': False, 'random_state': 10, 'criterion': 'gini'}
# 0.671 (+/-0.071) for {'max_features': 'sqrt', 'n_estimators': 50, 'oob_score': False, 'random_state': 20, 'criterion': 'gini'}
# 0.678 (+/-0.086) for {'max_features': 'sqrt', 'n_estimators': 50, 'oob_score': False, 'random_state': 30, 'criterion': 'gini'}
# 0.667 (+/-0.094) for {'max_features': 'sqrt', 'n_estimators': 100, 'oob_score': True, 'random_state': 0, 'criterion': 'gini'}
# 0.671 (+/-0.091) for {'max_features': 'sqrt', 'n_estimators': 100, 'oob_score': True, 'random_state': 10, 'criterion': 'gini'}
# 0.672 (+/-0.101) for {'max_features': 'sqrt', 'n_estimators': 100, 'oob_score': True, 'random_state': 20, 'criterion': 'gini'}
# 0.682 (+/-0.082) for {'max_features': 'sqrt', 'n_estimators': 100, 'oob_score': True, 'random_state': 30, 'criterion': 'gini'}
# 0.667 (+/-0.094) for {'max_features': 'sqrt', 'n_estimators': 100, 'oob_score': False, 'random_state': 0, 'criterion': 'gini'}
# 0.671 (+/-0.091) for {'max_features': 'sqrt', 'n_estimators': 100, 'oob_score': False, 'random_state': 10, 'criterion': 'gini'}
# 0.672 (+/-0.101) for {'max_features': 'sqrt', 'n_estimators': 100, 'oob_score': False, 'random_state': 20, 'criterion': 'gini'}
# 0.682 (+/-0.082) for {'max_features': 'sqrt', 'n_estimators': 100, 'oob_score': False, 'random_state': 30, 'criterion': 'gini'}
# 0.676 (+/-0.086) for {'max_features': 'sqrt', 'n_estimators': 200, 'oob_score': True, 'random_state': 0, 'criterion': 'gini'}
# 0.671 (+/-0.097) for {'max_features': 'sqrt', 'n_estimators': 200, 'oob_score': True, 'random_state': 10, 'criterion': 'gini'}
# 0.672 (+/-0.085) for {'max_features': 'sqrt', 'n_estimators': 200, 'oob_score': True, 'random_state': 20, 'criterion': 'gini'}
# 0.676 (+/-0.084) for {'max_features': 'sqrt', 'n_estimators': 200, 'oob_score': True, 'random_state': 30, 'criterion': 'gini'}
# 0.676 (+/-0.086) for {'max_features': 'sqrt', 'n_estimators': 200, 'oob_score': False, 'random_state': 0, 'criterion': 'gini'}
# 0.671 (+/-0.097) for {'max_features': 'sqrt', 'n_estimators': 200, 'oob_score': False, 'random_state': 10, 'criterion': 'gini'}
# 0.672 (+/-0.085) for {'max_features': 'sqrt', 'n_estimators': 200, 'oob_score': False, 'random_state': 20, 'criterion': 'gini'}
# 0.676 (+/-0.084) for {'max_features': 'sqrt', 'n_estimators': 200, 'oob_score': False, 'random_state': 30, 'criterion': 'gini'}
# 0.673 (+/-0.098) for {'max_features': 'sqrt', 'n_estimators': 500, 'oob_score': True, 'random_state': 0, 'criterion': 'gini'}
# 0.674 (+/-0.077) for {'max_features': 'sqrt', 'n_estimators': 500, 'oob_score': True, 'random_state': 10, 'criterion': 'gini'}
# 0.681 (+/-0.078) for {'max_features': 'sqrt', 'n_estimators': 500, 'oob_score': True, 'random_state': 20, 'criterion': 'gini'}
# 0.674 (+/-0.081) for {'max_features': 'sqrt', 'n_estimators': 500, 'oob_score': True, 'random_state': 30, 'criterion': 'gini'}
# 0.673 (+/-0.098) for {'max_features': 'sqrt', 'n_estimators': 500, 'oob_score': False, 'random_state': 0, 'criterion': 'gini'}
# 0.674 (+/-0.077) for {'max_features': 'sqrt', 'n_estimators': 500, 'oob_score': False, 'random_state': 10, 'criterion': 'gini'}
# 0.681 (+/-0.078) for {'max_features': 'sqrt', 'n_estimators': 500, 'oob_score': False, 'random_state': 20, 'criterion': 'gini'}
# 0.674 (+/-0.081) for {'max_features': 'sqrt', 'n_estimators': 500, 'oob_score': False, 'random_state': 30, 'criterion': 'gini'}
# 0.670 (+/-0.079) for {'max_features': 'log2', 'n_estimators': 50, 'oob_score': True, 'random_state': 0, 'criterion': 'gini'}
# 0.681 (+/-0.053) for {'max_features': 'log2', 'n_estimators': 50, 'oob_score': True, 'random_state': 10, 'criterion': 'gini'}
# 0.668 (+/-0.089) for {'max_features': 'log2', 'n_estimators': 50, 'oob_score': True, 'random_state': 20, 'criterion': 'gini'}
# 0.672 (+/-0.090) for {'max_features': 'log2', 'n_estimators': 50, 'oob_score': True, 'random_state': 30, 'criterion': 'gini'}
# 0.670 (+/-0.079) for {'max_features': 'log2', 'n_estimators': 50, 'oob_score': False, 'random_state': 0, 'criterion': 'gini'}
# 0.681 (+/-0.053) for {'max_features': 'log2', 'n_estimators': 50, 'oob_score': False, 'random_state': 10, 'criterion': 'gini'}
# 0.668 (+/-0.089) for {'max_features': 'log2', 'n_estimators': 50, 'oob_score': False, 'random_state': 20, 'criterion': 'gini'}
# 0.672 (+/-0.090) for {'max_features': 'log2', 'n_estimators': 50, 'oob_score': False, 'random_state': 30, 'criterion': 'gini'}
# 0.666 (+/-0.056) for {'max_features': 'log2', 'n_estimators': 100, 'oob_score': True, 'random_state': 0, 'criterion': 'gini'}
# 0.693 (+/-0.069) for {'max_features': 'log2', 'n_estimators': 100, 'oob_score': True, 'random_state': 10, 'criterion': 'gini'}
# 0.661 (+/-0.064) for {'max_features': 'log2', 'n_estimators': 100, 'oob_score': True, 'random_state': 20, 'criterion': 'gini'}
# 0.673 (+/-0.081) for {'max_features': 'log2', 'n_estimators': 100, 'oob_score': True, 'random_state': 30, 'criterion': 'gini'}
# 0.666 (+/-0.056) for {'max_features': 'log2', 'n_estimators': 100, 'oob_score': False, 'random_state': 0, 'criterion': 'gini'}
# 0.693 (+/-0.069) for {'max_features': 'log2', 'n_estimators': 100, 'oob_score': False, 'random_state': 10, 'criterion': 'gini'}
# 0.661 (+/-0.064) for {'max_features': 'log2', 'n_estimators': 100, 'oob_score': False, 'random_state': 20, 'criterion': 'gini'}
# 0.673 (+/-0.081) for {'max_features': 'log2', 'n_estimators': 100, 'oob_score': False, 'random_state': 30, 'criterion': 'gini'}
# 0.678 (+/-0.075) for {'max_features': 'log2', 'n_estimators': 200, 'oob_score': True, 'random_state': 0, 'criterion': 'gini'}
# 0.682 (+/-0.078) for {'max_features': 'log2', 'n_estimators': 200, 'oob_score': True, 'random_state': 10, 'criterion': 'gini'}
# 0.667 (+/-0.090) for {'max_features': 'log2', 'n_estimators': 200, 'oob_score': True, 'random_state': 20, 'criterion': 'gini'}
# 0.669 (+/-0.056) for {'max_features': 'log2', 'n_estimators': 200, 'oob_score': True, 'random_state': 30, 'criterion': 'gini'}
# 0.678 (+/-0.075) for {'max_features': 'log2', 'n_estimators': 200, 'oob_score': False, 'random_state': 0, 'criterion': 'gini'}
# 0.682 (+/-0.078) for {'max_features': 'log2', 'n_estimators': 200, 'oob_score': False, 'random_state': 10, 'criterion': 'gini'}
# 0.667 (+/-0.090) for {'max_features': 'log2', 'n_estimators': 200, 'oob_score': False, 'random_state': 20, 'criterion': 'gini'}
# 0.669 (+/-0.056) for {'max_features': 'log2', 'n_estimators': 200, 'oob_score': False, 'random_state': 30, 'criterion': 'gini'}
# 0.680 (+/-0.066) for {'max_features': 'log2', 'n_estimators': 500, 'oob_score': True, 'random_state': 0, 'criterion': 'gini'}
# 0.683 (+/-0.076) for {'max_features': 'log2', 'n_estimators': 500, 'oob_score': True, 'random_state': 10, 'criterion': 'gini'}
# 0.679 (+/-0.078) for {'max_features': 'log2', 'n_estimators': 500, 'oob_score': True, 'random_state': 20, 'criterion': 'gini'}
# 0.688 (+/-0.076) for {'max_features': 'log2', 'n_estimators': 500, 'oob_score': True, 'random_state': 30, 'criterion': 'gini'}
# 0.680 (+/-0.066) for {'max_features': 'log2', 'n_estimators': 500, 'oob_score': False, 'random_state': 0, 'criterion': 'gini'}
# 0.683 (+/-0.076) for {'max_features': 'log2', 'n_estimators': 500, 'oob_score': False, 'random_state': 10, 'criterion': 'gini'}
# 0.679 (+/-0.078) for {'max_features': 'log2', 'n_estimators': 500, 'oob_score': False, 'random_state': 20, 'criterion': 'gini'}
# 0.688 (+/-0.076) for {'max_features': 'log2', 'n_estimators': 500, 'oob_score': False, 'random_state': 30, 'criterion': 'gini'}
# 0.678 (+/-0.080) for {'max_features': None, 'n_estimators': 50, 'oob_score': True, 'random_state': 0, 'criterion': 'entropy'}
# 0.674 (+/-0.089) for {'max_features': None, 'n_estimators': 50, 'oob_score': True, 'random_state': 10, 'criterion': 'entropy'}
# 0.674 (+/-0.077) for {'max_features': None, 'n_estimators': 50, 'oob_score': True, 'random_state': 20, 'criterion': 'entropy'}
# 0.679 (+/-0.120) for {'max_features': None, 'n_estimators': 50, 'oob_score': True, 'random_state': 30, 'criterion': 'entropy'}
# 0.678 (+/-0.080) for {'max_features': None, 'n_estimators': 50, 'oob_score': False, 'random_state': 0, 'criterion': 'entropy'}
# 0.674 (+/-0.089) for {'max_features': None, 'n_estimators': 50, 'oob_score': False, 'random_state': 10, 'criterion': 'entropy'}
# 0.674 (+/-0.077) for {'max_features': None, 'n_estimators': 50, 'oob_score': False, 'random_state': 20, 'criterion': 'entropy'}
# 0.679 (+/-0.120) for {'max_features': None, 'n_estimators': 50, 'oob_score': False, 'random_state': 30, 'criterion': 'entropy'}
# 0.679 (+/-0.094) for {'max_features': None, 'n_estimators': 100, 'oob_score': True, 'random_state': 0, 'criterion': 'entropy'}
# 0.669 (+/-0.084) for {'max_features': None, 'n_estimators': 100, 'oob_score': True, 'random_state': 10, 'criterion': 'entropy'}
# 0.686 (+/-0.087) for {'max_features': None, 'n_estimators': 100, 'oob_score': True, 'random_state': 20, 'criterion': 'entropy'}
# 0.676 (+/-0.083) for {'max_features': None, 'n_estimators': 100, 'oob_score': True, 'random_state': 30, 'criterion': 'entropy'}
# 0.679 (+/-0.094) for {'max_features': None, 'n_estimators': 100, 'oob_score': False, 'random_state': 0, 'criterion': 'entropy'}
# 0.669 (+/-0.084) for {'max_features': None, 'n_estimators': 100, 'oob_score': False, 'random_state': 10, 'criterion': 'entropy'}
# 0.686 (+/-0.087) for {'max_features': None, 'n_estimators': 100, 'oob_score': False, 'random_state': 20, 'criterion': 'entropy'}
# 0.676 (+/-0.083) for {'max_features': None, 'n_estimators': 100, 'oob_score': False, 'random_state': 30, 'criterion': 'entropy'}
# 0.688 (+/-0.102) for {'max_features': None, 'n_estimators': 200, 'oob_score': True, 'random_state': 0, 'criterion': 'entropy'}
# 0.673 (+/-0.093) for {'max_features': None, 'n_estimators': 200, 'oob_score': True, 'random_state': 10, 'criterion': 'entropy'}
# 0.683 (+/-0.082) for {'max_features': None, 'n_estimators': 200, 'oob_score': True, 'random_state': 20, 'criterion': 'entropy'}
# 0.690 (+/-0.091) for {'max_features': None, 'n_estimators': 200, 'oob_score': True, 'random_state': 30, 'criterion': 'entropy'}
# 0.688 (+/-0.102) for {'max_features': None, 'n_estimators': 200, 'oob_score': False, 'random_state': 0, 'criterion': 'entropy'}
# 0.673 (+/-0.093) for {'max_features': None, 'n_estimators': 200, 'oob_score': False, 'random_state': 10, 'criterion': 'entropy'}
# 0.683 (+/-0.082) for {'max_features': None, 'n_estimators': 200, 'oob_score': False, 'random_state': 20, 'criterion': 'entropy'}
# 0.690 (+/-0.091) for {'max_features': None, 'n_estimators': 200, 'oob_score': False, 'random_state': 30, 'criterion': 'entropy'}
# 0.676 (+/-0.102) for {'max_features': None, 'n_estimators': 500, 'oob_score': True, 'random_state': 0, 'criterion': 'entropy'}
# 0.666 (+/-0.091) for {'max_features': None, 'n_estimators': 500, 'oob_score': True, 'random_state': 10, 'criterion': 'entropy'}
# 0.674 (+/-0.096) for {'max_features': None, 'n_estimators': 500, 'oob_score': True, 'random_state': 20, 'criterion': 'entropy'}
# 0.688 (+/-0.094) for {'max_features': None, 'n_estimators': 500, 'oob_score': True, 'random_state': 30, 'criterion': 'entropy'}
# 0.676 (+/-0.102) for {'max_features': None, 'n_estimators': 500, 'oob_score': False, 'random_state': 0, 'criterion': 'entropy'}
# 0.666 (+/-0.091) for {'max_features': None, 'n_estimators': 500, 'oob_score': False, 'random_state': 10, 'criterion': 'entropy'}
# 0.674 (+/-0.096) for {'max_features': None, 'n_estimators': 500, 'oob_score': False, 'random_state': 20, 'criterion': 'entropy'}
# 0.688 (+/-0.094) for {'max_features': None, 'n_estimators': 500, 'oob_score': False, 'random_state': 30, 'criterion': 'entropy'}
# 0.664 (+/-0.084) for {'max_features': 'sqrt', 'n_estimators': 50, 'oob_score': True, 'random_state': 0, 'criterion': 'entropy'}
# 0.673 (+/-0.109) for {'max_features': 'sqrt', 'n_estimators': 50, 'oob_score': True, 'random_state': 10, 'criterion': 'entropy'}
# 0.677 (+/-0.093) for {'max_features': 'sqrt', 'n_estimators': 50, 'oob_score': True, 'random_state': 20, 'criterion': 'entropy'}
# 0.670 (+/-0.091) for {'max_features': 'sqrt', 'n_estimators': 50, 'oob_score': True, 'random_state': 30, 'criterion': 'entropy'}
# 0.664 (+/-0.084) for {'max_features': 'sqrt', 'n_estimators': 50, 'oob_score': False, 'random_state': 0, 'criterion': 'entropy'}
# 0.673 (+/-0.109) for {'max_features': 'sqrt', 'n_estimators': 50, 'oob_score': False, 'random_state': 10, 'criterion': 'entropy'}
# 0.677 (+/-0.093) for {'max_features': 'sqrt', 'n_estimators': 50, 'oob_score': False, 'random_state': 20, 'criterion': 'entropy'}
# 0.670 (+/-0.091) for {'max_features': 'sqrt', 'n_estimators': 50, 'oob_score': False, 'random_state': 30, 'criterion': 'entropy'}
# 0.671 (+/-0.107) for {'max_features': 'sqrt', 'n_estimators': 100, 'oob_score': True, 'random_state': 0, 'criterion': 'entropy'}
# 0.677 (+/-0.082) for {'max_features': 'sqrt', 'n_estimators': 100, 'oob_score': True, 'random_state': 10, 'criterion': 'entropy'}
# 0.679 (+/-0.106) for {'max_features': 'sqrt', 'n_estimators': 100, 'oob_score': True, 'random_state': 20, 'criterion': 'entropy'}
# 0.677 (+/-0.084) for {'max_features': 'sqrt', 'n_estimators': 100, 'oob_score': True, 'random_state': 30, 'criterion': 'entropy'}
# 0.671 (+/-0.107) for {'max_features': 'sqrt', 'n_estimators': 100, 'oob_score': False, 'random_state': 0, 'criterion': 'entropy'}
# 0.677 (+/-0.082) for {'max_features': 'sqrt', 'n_estimators': 100, 'oob_score': False, 'random_state': 10, 'criterion': 'entropy'}
# 0.679 (+/-0.106) for {'max_features': 'sqrt', 'n_estimators': 100, 'oob_score': False, 'random_state': 20, 'criterion': 'entropy'}
# 0.677 (+/-0.084) for {'max_features': 'sqrt', 'n_estimators': 100, 'oob_score': False, 'random_state': 30, 'criterion': 'entropy'}
# 0.680 (+/-0.109) for {'max_features': 'sqrt', 'n_estimators': 200, 'oob_score': True, 'random_state': 0, 'criterion': 'entropy'}
# 0.687 (+/-0.093) for {'max_features': 'sqrt', 'n_estimators': 200, 'oob_score': True, 'random_state': 10, 'criterion': 'entropy'}
# 0.680 (+/-0.091) for {'max_features': 'sqrt', 'n_estimators': 200, 'oob_score': True, 'random_state': 20, 'criterion': 'entropy'}
# 0.677 (+/-0.085) for {'max_features': 'sqrt', 'n_estimators': 200, 'oob_score': True, 'random_state': 30, 'criterion': 'entropy'}
# 0.680 (+/-0.109) for {'max_features': 'sqrt', 'n_estimators': 200, 'oob_score': False, 'random_state': 0, 'criterion': 'entropy'}
# 0.687 (+/-0.093) for {'max_features': 'sqrt', 'n_estimators': 200, 'oob_score': False, 'random_state': 10, 'criterion': 'entropy'}
# 0.680 (+/-0.091) for {'max_features': 'sqrt', 'n_estimators': 200, 'oob_score': False, 'random_state': 20, 'criterion': 'entropy'}
# 0.677 (+/-0.085) for {'max_features': 'sqrt', 'n_estimators': 200, 'oob_score': False, 'random_state': 30, 'criterion': 'entropy'}
# 0.674 (+/-0.101) for {'max_features': 'sqrt', 'n_estimators': 500, 'oob_score': True, 'random_state': 0, 'criterion': 'entropy'}
# 0.674 (+/-0.068) for {'max_features': 'sqrt', 'n_estimators': 500, 'oob_score': True, 'random_state': 10, 'criterion': 'entropy'}
# 0.683 (+/-0.093) for {'max_features': 'sqrt', 'n_estimators': 500, 'oob_score': True, 'random_state': 20, 'criterion': 'entropy'}
# 0.681 (+/-0.084) for {'max_features': 'sqrt', 'n_estimators': 500, 'oob_score': True, 'random_state': 30, 'criterion': 'entropy'}
# 0.674 (+/-0.101) for {'max_features': 'sqrt', 'n_estimators': 500, 'oob_score': False, 'random_state': 0, 'criterion': 'entropy'}
# 0.674 (+/-0.068) for {'max_features': 'sqrt', 'n_estimators': 500, 'oob_score': False, 'random_state': 10, 'criterion': 'entropy'}
# 0.683 (+/-0.093) for {'max_features': 'sqrt', 'n_estimators': 500, 'oob_score': False, 'random_state': 20, 'criterion': 'entropy'}
# 0.681 (+/-0.084) for {'max_features': 'sqrt', 'n_estimators': 500, 'oob_score': False, 'random_state': 30, 'criterion': 'entropy'}
# 0.670 (+/-0.089) for {'max_features': 'log2', 'n_estimators': 50, 'oob_score': True, 'random_state': 0, 'criterion': 'entropy'}
# 0.657 (+/-0.098) for {'max_features': 'log2', 'n_estimators': 50, 'oob_score': True, 'random_state': 10, 'criterion': 'entropy'}
# 0.673 (+/-0.078) for {'max_features': 'log2', 'n_estimators': 50, 'oob_score': True, 'random_state': 20, 'criterion': 'entropy'}
# 0.670 (+/-0.089) for {'max_features': 'log2', 'n_estimators': 50, 'oob_score': True, 'random_state': 30, 'criterion': 'entropy'}
# 0.670 (+/-0.089) for {'max_features': 'log2', 'n_estimators': 50, 'oob_score': False, 'random_state': 0, 'criterion': 'entropy'}
# 0.657 (+/-0.098) for {'max_features': 'log2', 'n_estimators': 50, 'oob_score': False, 'random_state': 10, 'criterion': 'entropy'}
# 0.673 (+/-0.078) for {'max_features': 'log2', 'n_estimators': 50, 'oob_score': False, 'random_state': 20, 'criterion': 'entropy'}
# 0.670 (+/-0.089) for {'max_features': 'log2', 'n_estimators': 50, 'oob_score': False, 'random_state': 30, 'criterion': 'entropy'}
# 0.670 (+/-0.078) for {'max_features': 'log2', 'n_estimators': 100, 'oob_score': True, 'random_state': 0, 'criterion': 'entropy'}
# 0.681 (+/-0.086) for {'max_features': 'log2', 'n_estimators': 100, 'oob_score': True, 'random_state': 10, 'criterion': 'entropy'}
# 0.676 (+/-0.069) for {'max_features': 'log2', 'n_estimators': 100, 'oob_score': True, 'random_state': 20, 'criterion': 'entropy'}
# 0.667 (+/-0.067) for {'max_features': 'log2', 'n_estimators': 100, 'oob_score': True, 'random_state': 30, 'criterion': 'entropy'}
# 0.670 (+/-0.078) for {'max_features': 'log2', 'n_estimators': 100, 'oob_score': False, 'random_state': 0, 'criterion': 'entropy'}
# 0.681 (+/-0.086) for {'max_features': 'log2', 'n_estimators': 100, 'oob_score': False, 'random_state': 10, 'criterion': 'entropy'}
# 0.676 (+/-0.069) for {'max_features': 'log2', 'n_estimators': 100, 'oob_score': False, 'random_state': 20, 'criterion': 'entropy'}
# 0.667 (+/-0.067) for {'max_features': 'log2', 'n_estimators': 100, 'oob_score': False, 'random_state': 30, 'criterion': 'entropy'}
# 0.669 (+/-0.069) for {'max_features': 'log2', 'n_estimators': 200, 'oob_score': True, 'random_state': 0, 'criterion': 'entropy'}
# 0.679 (+/-0.073) for {'max_features': 'log2', 'n_estimators': 200, 'oob_score': True, 'random_state': 10, 'criterion': 'entropy'}
# 0.680 (+/-0.093) for {'max_features': 'log2', 'n_estimators': 200, 'oob_score': True, 'random_state': 20, 'criterion': 'entropy'}
# 0.670 (+/-0.074) for {'max_features': 'log2', 'n_estimators': 200, 'oob_score': True, 'random_state': 30, 'criterion': 'entropy'}
# 0.669 (+/-0.069) for {'max_features': 'log2', 'n_estimators': 200, 'oob_score': False, 'random_state': 0, 'criterion': 'entropy'}
# 0.679 (+/-0.073) for {'max_features': 'log2', 'n_estimators': 200, 'oob_score': False, 'random_state': 10, 'criterion': 'entropy'}
# 0.680 (+/-0.093) for {'max_features': 'log2', 'n_estimators': 200, 'oob_score': False, 'random_state': 20, 'criterion': 'entropy'}
# 0.670 (+/-0.074) for {'max_features': 'log2', 'n_estimators': 200, 'oob_score': False, 'random_state': 30, 'criterion': 'entropy'}
# 0.674 (+/-0.070) for {'max_features': 'log2', 'n_estimators': 500, 'oob_score': True, 'random_state': 0, 'criterion': 'entropy'}
# 0.672 (+/-0.081) for {'max_features': 'log2', 'n_estimators': 500, 'oob_score': True, 'random_state': 10, 'criterion': 'entropy'}
# 0.679 (+/-0.092) for {'max_features': 'log2', 'n_estimators': 500, 'oob_score': True, 'random_state': 20, 'criterion': 'entropy'}
# 0.678 (+/-0.064) for {'max_features': 'log2', 'n_estimators': 500, 'oob_score': True, 'random_state': 30, 'criterion': 'entropy'}
# 0.674 (+/-0.070) for {'max_features': 'log2', 'n_estimators': 500, 'oob_score': False, 'random_state': 0, 'criterion': 'entropy'}
# 0.672 (+/-0.081) for {'max_features': 'log2', 'n_estimators': 500, 'oob_score': False, 'random_state': 10, 'criterion': 'entropy'}
# 0.679 (+/-0.092) for {'max_features': 'log2', 'n_estimators': 500, 'oob_score': False, 'random_state': 20, 'criterion': 'entropy'}
# 0.678 (+/-0.064) for {'max_features': 'log2', 'n_estimators': 500, 'oob_score': False, 'random_state': 30, 'criterion': 'entropy'}
#
# Best Score:
#
#
# Best Params:
#
# 0.693333333333
# {'max_features': 'log2', 'n_estimators': 100, 'oob_score': True, 'random_state': 10, 'criterion': 'gini'}
#
# Classification Report:
#
#              precision    recall  f1-score   support
#
#           1       0.00      0.00      0.00        14
#           2       0.00      0.00      0.00        13
#           3       0.20      0.02      0.04        86
#           4       0.48      0.23      0.31       625
#           5       0.68      0.90      0.78      1362
#
# avg / total       0.60      0.65      0.60      2100
#
#
# >> End Processing RandomForestClassifier
#
# >> Start Processing LogisticRegression
# /home/ayush/Desktop/gsresult/LogisticRegression
# Grid Scores:
#
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0001}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0002}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0003}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.004}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0001}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0002}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0003}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.004}
# 0.621 (+/-0.058) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0001}
# 0.619 (+/-0.076) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0002}
# 0.582 (+/-0.060) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0003}
# 0.576 (+/-0.068) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.004}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0001}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0002}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0003}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.004}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0001}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0002}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0003}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.004}
# 0.621 (+/-0.058) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0001}
# 0.619 (+/-0.076) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0002}
# 0.582 (+/-0.060) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0003}
# 0.576 (+/-0.068) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.004}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0001}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0002}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0003}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.004}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0001}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0002}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0003}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.004}
# 0.621 (+/-0.058) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0001}
# 0.619 (+/-0.076) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0002}
# 0.582 (+/-0.060) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0003}
# 0.576 (+/-0.068) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.004}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0001}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0002}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0003}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.004}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0001}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0002}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0003}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.004}
# 0.621 (+/-0.058) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0001}
# 0.619 (+/-0.076) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0002}
# 0.582 (+/-0.060) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0003}
# 0.576 (+/-0.068) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.004}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0001}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0002}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0003}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.004}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0001}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0002}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0003}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.004}
# 0.621 (+/-0.058) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0001}
# 0.619 (+/-0.076) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0002}
# 0.582 (+/-0.060) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0003}
# 0.576 (+/-0.068) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.004}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0001}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0002}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0003}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.004}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0001}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0002}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0003}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.004}
# 0.621 (+/-0.058) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0001}
# 0.619 (+/-0.076) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0002}
# 0.582 (+/-0.060) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0003}
# 0.576 (+/-0.068) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.004}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0001}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0002}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0003}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.004}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0001}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0002}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0003}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.004}
# 0.621 (+/-0.058) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0001}
# 0.619 (+/-0.076) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0002}
# 0.582 (+/-0.060) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0003}
# 0.576 (+/-0.068) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.004}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0001}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0002}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0003}
# 0.658 (+/-0.045) for {'fit_intercept': True, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.004}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0001}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0002}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0003}
# 0.582 (+/-0.057) for {'fit_intercept': True, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.004}
# 0.621 (+/-0.058) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0001}
# 0.619 (+/-0.076) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0002}
# 0.582 (+/-0.060) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0003}
# 0.576 (+/-0.068) for {'fit_intercept': True, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.004}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0001}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0002}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0003}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.004}
# 0.582 (+/-0.057) for {'fit_intercept': False, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0001}
# 0.582 (+/-0.057) for {'fit_intercept': False, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0002}
# 0.582 (+/-0.057) for {'fit_intercept': False, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0003}
# 0.582 (+/-0.057) for {'fit_intercept': False, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.004}
# 0.524 (+/-0.102) for {'fit_intercept': False, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0001}
# 0.550 (+/-0.120) for {'fit_intercept': False, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0002}
# 0.558 (+/-0.117) for {'fit_intercept': False, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0003}
# 0.577 (+/-0.065) for {'fit_intercept': False, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.004}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0001}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0002}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0003}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.004}
# 0.582 (+/-0.057) for {'fit_intercept': False, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0001}
# 0.582 (+/-0.057) for {'fit_intercept': False, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0002}
# 0.582 (+/-0.057) for {'fit_intercept': False, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0003}
# 0.582 (+/-0.057) for {'fit_intercept': False, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.004}
# 0.524 (+/-0.102) for {'fit_intercept': False, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0001}
# 0.550 (+/-0.120) for {'fit_intercept': False, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0002}
# 0.558 (+/-0.117) for {'fit_intercept': False, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.0003}
# 0.577 (+/-0.065) for {'fit_intercept': False, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 10, 'tol': 0.004}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0001}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0002}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0003}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.004}
# 0.582 (+/-0.057) for {'fit_intercept': False, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0001}
# 0.582 (+/-0.057) for {'fit_intercept': False, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0002}
# 0.582 (+/-0.057) for {'fit_intercept': False, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0003}
# 0.582 (+/-0.057) for {'fit_intercept': False, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.004}
# 0.524 (+/-0.102) for {'fit_intercept': False, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0001}
# 0.550 (+/-0.120) for {'fit_intercept': False, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0002}
# 0.558 (+/-0.117) for {'fit_intercept': False, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.0003}
# 0.577 (+/-0.065) for {'fit_intercept': False, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 20, 'tol': 0.004}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0001}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0002}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0003}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.004}
# 0.582 (+/-0.057) for {'fit_intercept': False, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0001}
# 0.582 (+/-0.057) for {'fit_intercept': False, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0002}
# 0.582 (+/-0.057) for {'fit_intercept': False, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0003}
# 0.582 (+/-0.057) for {'fit_intercept': False, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.004}
# 0.524 (+/-0.102) for {'fit_intercept': False, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0001}
# 0.550 (+/-0.120) for {'fit_intercept': False, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0002}
# 0.558 (+/-0.117) for {'fit_intercept': False, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.0003}
# 0.577 (+/-0.065) for {'fit_intercept': False, 'C': 1.0, 'solver': 'liblinear', 'max_iter': 1000, 'multi_class': 'ovr', 'random_state': 30, 'tol': 0.004}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0001}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0002}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0003}
# 0.531 (+/-0.078) for {'fit_intercept': False, 'C': 1.0, 'solver': 'newton-cg', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.004}
# 0.582 (+/-0.057) for {'fit_intercept': False, 'C': 1.0, 'solver': 'lbfgs', 'max_iter': 1500, 'multi_class': 'ovr', 'random_state': 0, 'tol': 0.0001}
# ...
# 0.576 (+/-0.103) for {'max_features': 'log2', 'splitter': 'random', 'random_state': 10, 'criterion': 'entropy'}
# 0.578 (+/-0.096) for {'max_features': 'log2', 'splitter': 'best', 'random_state': 10, 'criterion': 'entropy'}
# 0.580 (+/-0.093) for {'max_features': 'log2', 'splitter': 'random', 'random_state': 20, 'criterion': 'entropy'}
# 0.609 (+/-0.107) for {'max_features': 'log2', 'splitter': 'best', 'random_state': 20, 'criterion': 'entropy'}
# 0.557 (+/-0.122) for {'max_features': 'log2', 'splitter': 'random', 'random_state': 30, 'criterion': 'entropy'}
# 0.558 (+/-0.092) for {'max_features': 'log2', 'splitter': 'best', 'random_state': 30, 'criterion': 'entropy'}
#
# Best Score:
#
#
# Best Params:
#
# 0.608888888889
# {'max_features': 'auto', 'splitter': 'best', 'random_state': 0, 'criterion': 'entropy'}
#
# Classification Report:
#
#              precision    recall  f1-score   support
#
#           1       0.00      0.00      0.00        14
#           2       0.00      0.00      0.00        13
#           3       0.05      0.06      0.06        86
#           4       0.38      0.43      0.41       625
#           5       0.70      0.66      0.68      1362
#
# avg / total       0.57      0.56      0.56      2100
#
#
# >> End Processing DecisionTreeClassifier
#
# >> Start Processing KNeighborsClassifier
# /home/ayush/Desktop/gsresult/KNeighborsClassifier
# Grid Scores:
#
# 0.597 (+/-0.089) for {'n_neighbors': 5, 'metric': 'euclidean', 'weights': 'uniform', 'algorithm': 'auto'}
# 0.596 (+/-0.056) for {'n_neighbors': 5, 'metric': 'euclidean', 'weights': 'distance', 'algorithm': 'auto'}
# 0.584 (+/-0.082) for {'n_neighbors': 10, 'metric': 'euclidean', 'weights': 'uniform', 'algorithm': 'auto'}
# 0.606 (+/-0.082) for {'n_neighbors': 10, 'metric': 'euclidean', 'weights': 'distance', 'algorithm': 'auto'}
# 0.613 (+/-0.064) for {'n_neighbors': 15, 'metric': 'euclidean', 'weights': 'uniform', 'algorithm': 'auto'}
# 0.614 (+/-0.063) for {'n_neighbors': 15, 'metric': 'euclidean', 'weights': 'distance', 'algorithm': 'auto'}
# 0.610 (+/-0.080) for {'n_neighbors': 20, 'metric': 'euclidean', 'weights': 'uniform', 'algorithm': 'auto'}
# 0.611 (+/-0.064) for {'n_neighbors': 20, 'metric': 'euclidean', 'weights': 'distance', 'algorithm': 'auto'}
# 0.602 (+/-0.056) for {'n_neighbors': 5, 'metric': 'manhattan', 'weights': 'uniform', 'algorithm': 'auto'}
# 0.598 (+/-0.062) for {'n_neighbors': 5, 'metric': 'manhattan', 'weights': 'distance', 'algorithm': 'auto'}
# 0.594 (+/-0.080) for {'n_neighbors': 10, 'metric': 'manhattan', 'weights': 'uniform', 'algorithm': 'auto'}
# 0.610 (+/-0.094) for {'n_neighbors': 10, 'metric': 'manhattan', 'weights': 'distance', 'algorithm': 'auto'}
# 0.621 (+/-0.080) for {'n_neighbors': 15, 'metric': 'manhattan', 'weights': 'uniform', 'algorithm': 'auto'}
# 0.618 (+/-0.073) for {'n_neighbors': 15, 'metric': 'manhattan', 'weights': 'distance', 'algorithm': 'auto'}
# 0.613 (+/-0.085) for {'n_neighbors': 20, 'metric': 'manhattan', 'weights': 'uniform', 'algorithm': 'auto'}
# 0.619 (+/-0.057) for {'n_neighbors': 20, 'metric': 'manhattan', 'weights': 'distance', 'algorithm': 'auto'}
# 0.587 (+/-0.085) for {'n_neighbors': 5, 'metric': 'chebyshev', 'weights': 'uniform', 'algorithm': 'auto'}
# 0.603 (+/-0.058) for {'n_neighbors': 5, 'metric': 'chebyshev', 'weights': 'distance', 'algorithm': 'auto'}
# 0.581 (+/-0.084) for {'n_neighbors': 10, 'metric': 'chebyshev', 'weights': 'uniform', 'algorithm': 'auto'}
# 0.601 (+/-0.078) for {'n_neighbors': 10, 'metric': 'chebyshev', 'weights': 'distance', 'algorithm': 'auto'}
# 0.608 (+/-0.055) for {'n_neighbors': 15, 'metric': 'chebyshev', 'weights': 'uniform', 'algorithm': 'auto'}
# 0.607 (+/-0.072) for {'n_neighbors': 15, 'metric': 'chebyshev', 'weights': 'distance', 'algorithm': 'auto'}
# 0.606 (+/-0.069) for {'n_neighbors': 20, 'metric': 'chebyshev', 'weights': 'uniform', 'algorithm': 'auto'}
# 0.611 (+/-0.056) for {'n_neighbors': 20, 'metric': 'chebyshev', 'weights': 'distance', 'algorithm': 'auto'}
# 0.597 (+/-0.089) for {'n_neighbors': 5, 'metric': 'minkowski', 'weights': 'uniform', 'algorithm': 'auto'}
# 0.596 (+/-0.056) for {'n_neighbors': 5, 'metric': 'minkowski', 'weights': 'distance', 'algorithm': 'auto'}
# 0.584 (+/-0.082) for {'n_neighbors': 10, 'metric': 'minkowski', 'weights': 'uniform', 'algorithm': 'auto'}
# 0.606 (+/-0.082) for {'n_neighbors': 10, 'metric': 'minkowski', 'weights': 'distance', 'algorithm': 'auto'}
# 0.613 (+/-0.064) for {'n_neighbors': 15, 'metric': 'minkowski', 'weights': 'uniform', 'algorithm': 'auto'}
# 0.614 (+/-0.063) for {'n_neighbors': 15, 'metric': 'minkowski', 'weights': 'distance', 'algorithm': 'auto'}
# 0.610 (+/-0.080) for {'n_neighbors': 20, 'metric': 'minkowski', 'weights': 'uniform', 'algorithm': 'auto'}
# 0.611 (+/-0.064) for {'n_neighbors': 20, 'metric': 'minkowski', 'weights': 'distance', 'algorithm': 'auto'}
# 0.597 (+/-0.089) for {'n_neighbors': 5, 'metric': 'euclidean', 'weights': 'uniform', 'algorithm': 'ball_tree'}
# 0.596 (+/-0.056) for {'n_neighbors': 5, 'metric': 'euclidean', 'weights': 'distance', 'algorithm': 'ball_tree'}
# 0.584 (+/-0.082) for {'n_neighbors': 10, 'metric': 'euclidean', 'weights': 'uniform', 'algorithm': 'ball_tree'}
# 0.606 (+/-0.082) for {'n_neighbors': 10, 'metric': 'euclidean', 'weights': 'distance', 'algorithm': 'ball_tree'}
# 0.613 (+/-0.064) for {'n_neighbors': 15, 'metric': 'euclidean', 'weights': 'uniform', 'algorithm': 'ball_tree'}
# 0.614 (+/-0.063) for {'n_neighbors': 15, 'metric': 'euclidean', 'weights': 'distance', 'algorithm': 'ball_tree'}
# 0.610 (+/-0.080) for {'n_neighbors': 20, 'metric': 'euclidean', 'weights': 'uniform', 'algorithm': 'ball_tree'}
# 0.611 (+/-0.064) for {'n_neighbors': 20, 'metric': 'euclidean', 'weights': 'distance', 'algorithm': 'ball_tree'}
# 0.602 (+/-0.056) for {'n_neighbors': 5, 'metric': 'manhattan', 'weights': 'uniform', 'algorithm': 'ball_tree'}
# 0.598 (+/-0.062) for {'n_neighbors': 5, 'metric': 'manhattan', 'weights': 'distance', 'algorithm': 'ball_tree'}
# 0.594 (+/-0.080) for {'n_neighbors': 10, 'metric': 'manhattan', 'weights': 'uniform', 'algorithm': 'ball_tree'}
# 0.610 (+/-0.094) for {'n_neighbors': 10, 'metric': 'manhattan', 'weights': 'distance', 'algorithm': 'ball_tree'}
# 0.621 (+/-0.080) for {'n_neighbors': 15, 'metric': 'manhattan', 'weights': 'uniform', 'algorithm': 'ball_tree'}
# 0.618 (+/-0.073) for {'n_neighbors': 15, 'metric': 'manhattan', 'weights': 'distance', 'algorithm': 'ball_tree'}
# 0.613 (+/-0.085) for {'n_neighbors': 20, 'metric': 'manhattan', 'weights': 'uniform', 'algorithm': 'ball_tree'}
# 0.619 (+/-0.057) for {'n_neighbors': 20, 'metric': 'manhattan', 'weights': 'distance', 'algorithm': 'ball_tree'}
# 0.587 (+/-0.085) for {'n_neighbors': 5, 'metric': 'chebyshev', 'weights': 'uniform', 'algorithm': 'ball_tree'}
# 0.603 (+/-0.058) for {'n_neighbors': 5, 'metric': 'chebyshev', 'weights': 'distance', 'algorithm': 'ball_tree'}
# 0.581 (+/-0.084) for {'n_neighbors': 10, 'metric': 'chebyshev', 'weights': 'uniform', 'algorithm': 'ball_tree'}
# 0.601 (+/-0.078) for {'n_neighbors': 10, 'metric': 'chebyshev', 'weights': 'distance', 'algorithm': 'ball_tree'}
# 0.608 (+/-0.055) for {'n_neighbors': 15, 'metric': 'chebyshev', 'weights': 'uniform', 'algorithm': 'ball_tree'}
# 0.607 (+/-0.072) for {'n_neighbors': 15, 'metric': 'chebyshev', 'weights': 'distance', 'algorithm': 'ball_tree'}
# 0.606 (+/-0.069) for {'n_neighbors': 20, 'metric': 'chebyshev', 'weights': 'uniform', 'algorithm': 'ball_tree'}
# 0.611 (+/-0.056) for {'n_neighbors': 20, 'metric': 'chebyshev', 'weights': 'distance', 'algorithm': 'ball_tree'}
# 0.597 (+/-0.089) for {'n_neighbors': 5, 'metric': 'minkowski', 'weights': 'uniform', 'algorithm': 'ball_tree'}
# 0.596 (+/-0.056) for {'n_neighbors': 5, 'metric': 'minkowski', 'weights': 'distance', 'algorithm': 'ball_tree'}
# 0.584 (+/-0.082) for {'n_neighbors': 10, 'metric': 'minkowski', 'weights': 'uniform', 'algorithm': 'ball_tree'}
# 0.606 (+/-0.082) for {'n_neighbors': 10, 'metric': 'minkowski', 'weights': 'distance', 'algorithm': 'ball_tree'}
# 0.613 (+/-0.064) for {'n_neighbors': 15, 'metric': 'minkowski', 'weights': 'uniform', 'algorithm': 'ball_tree'}
# 0.614 (+/-0.063) for {'n_neighbors': 15, 'metric': 'minkowski', 'weights': 'distance', 'algorithm': 'ball_tree'}
# 0.610 (+/-0.080) for {'n_neighbors': 20, 'metric': 'minkowski', 'weights': 'uniform', 'algorithm': 'ball_tree'}
# 0.611 (+/-0.064) for {'n_neighbors': 20, 'metric': 'minkowski', 'weights': 'distance', 'algorithm': 'ball_tree'}
# 0.597 (+/-0.089) for {'n_neighbors': 5, 'metric': 'euclidean', 'weights': 'uniform', 'algorithm': 'kd_tree'}
# 0.596 (+/-0.056) for {'n_neighbors': 5, 'metric': 'euclidean', 'weights': 'distance', 'algorithm': 'kd_tree'}
# 0.584 (+/-0.082) for {'n_neighbors': 10, 'metric': 'euclidean', 'weights': 'uniform', 'algorithm': 'kd_tree'}
# 0.606 (+/-0.082) for {'n_neighbors': 10, 'metric': 'euclidean', 'weights': 'distance', 'algorithm': 'kd_tree'}
# 0.613 (+/-0.064) for {'n_neighbors': 15, 'metric': 'euclidean', 'weights': 'uniform', 'algorithm': 'kd_tree'}
# 0.614 (+/-0.063) for {'n_neighbors': 15, 'metric': 'euclidean', 'weights': 'distance', 'algorithm': 'kd_tree'}
# 0.610 (+/-0.080) for {'n_neighbors': 20, 'metric': 'euclidean', 'weights': 'uniform', 'algorithm': 'kd_tree'}
# 0.611 (+/-0.064) for {'n_neighbors': 20, 'metric': 'euclidean', 'weights': 'distance', 'algorithm': 'kd_tree'}
# 0.602 (+/-0.056) for {'n_neighbors': 5, 'metric': 'manhattan', 'weights': 'uniform', 'algorithm': 'kd_tree'}
# 0.598 (+/-0.062) for {'n_neighbors': 5, 'metric': 'manhattan', 'weights': 'distance', 'algorithm': 'kd_tree'}
# 0.594 (+/-0.080) for {'n_neighbors': 10, 'metric': 'manhattan', 'weights': 'uniform', 'algorithm': 'kd_tree'}
# 0.610 (+/-0.094) for {'n_neighbors': 10, 'metric': 'manhattan', 'weights': 'distance', 'algorithm': 'kd_tree'}
# 0.621 (+/-0.080) for {'n_neighbors': 15, 'metric': 'manhattan', 'weights': 'uniform', 'algorithm': 'kd_tree'}
# 0.618 (+/-0.073) for {'n_neighbors': 15, 'metric': 'manhattan', 'weights': 'distance', 'algorithm': 'kd_tree'}
# 0.613 (+/-0.085) for {'n_neighbors': 20, 'metric': 'manhattan', 'weights': 'uniform', 'algorithm': 'kd_tree'}
# 0.619 (+/-0.057) for {'n_neighbors': 20, 'metric': 'manhattan', 'weights': 'distance', 'algorithm': 'kd_tree'}
# 0.587 (+/-0.085) for {'n_neighbors': 5, 'metric': 'chebyshev', 'weights': 'uniform', 'algorithm': 'kd_tree'}
# 0.603 (+/-0.058) for {'n_neighbors': 5, 'metric': 'chebyshev', 'weights': 'distance', 'algorithm': 'kd_tree'}
# 0.581 (+/-0.084) for {'n_neighbors': 10, 'metric': 'chebyshev', 'weights': 'uniform', 'algorithm': 'kd_tree'}
# 0.601 (+/-0.078) for {'n_neighbors': 10, 'metric': 'chebyshev', 'weights': 'distance', 'algorithm': 'kd_tree'}
# 0.608 (+/-0.055) for {'n_neighbors': 15, 'metric': 'chebyshev', 'weights': 'uniform', 'algorithm': 'kd_tree'}
# 0.607 (+/-0.072) for {'n_neighbors': 15, 'metric': 'chebyshev', 'weights': 'distance', 'algorithm': 'kd_tree'}
# 0.606 (+/-0.069) for {'n_neighbors': 20, 'metric': 'chebyshev', 'weights': 'uniform', 'algorithm': 'kd_tree'}
# 0.611 (+/-0.056) for {'n_neighbors': 20, 'metric': 'chebyshev', 'weights': 'distance', 'algorithm': 'kd_tree'}
# 0.597 (+/-0.089) for {'n_neighbors': 5, 'metric': 'minkowski', 'weights': 'uniform', 'algorithm': 'kd_tree'}
# 0.596 (+/-0.056) for {'n_neighbors': 5, 'metric': 'minkowski', 'weights': 'distance', 'algorithm': 'kd_tree'}
# 0.584 (+/-0.082) for {'n_neighbors': 10, 'metric': 'minkowski', 'weights': 'uniform', 'algorithm': 'kd_tree'}
# 0.606 (+/-0.082) for {'n_neighbors': 10, 'metric': 'minkowski', 'weights': 'distance', 'algorithm': 'kd_tree'}
# 0.613 (+/-0.064) for {'n_neighbors': 15, 'metric': 'minkowski', 'weights': 'uniform', 'algorithm': 'kd_tree'}
# 0.614 (+/-0.063) for {'n_neighbors': 15, 'metric': 'minkowski', 'weights': 'distance', 'algorithm': 'kd_tree'}
# 0.610 (+/-0.080) for {'n_neighbors': 20, 'metric': 'minkowski', 'weights': 'uniform', 'algorithm': 'kd_tree'}
# 0.611 (+/-0.064) for {'n_neighbors': 20, 'metric': 'minkowski', 'weights': 'distance', 'algorithm': 'kd_tree'}
# 0.597 (+/-0.089) for {'n_neighbors': 5, 'metric': 'euclidean', 'weights': 'uniform', 'algorithm': 'brute'}
# 0.596 (+/-0.056) for {'n_neighbors': 5, 'metric': 'euclidean', 'weights': 'distance', 'algorithm': 'brute'}
# 0.584 (+/-0.082) for {'n_neighbors': 10, 'metric': 'euclidean', 'weights': 'uniform', 'algorithm': 'brute'}
# 0.606 (+/-0.082) for {'n_neighbors': 10, 'metric': 'euclidean', 'weights': 'distance', 'algorithm': 'brute'}
# 0.613 (+/-0.064) for {'n_neighbors': 15, 'metric': 'euclidean', 'weights': 'uniform', 'algorithm': 'brute'}
# 0.614 (+/-0.063) for {'n_neighbors': 15, 'metric': 'euclidean', 'weights': 'distance', 'algorithm': 'brute'}
# 0.610 (+/-0.080) for {'n_neighbors': 20, 'metric': 'euclidean', 'weights': 'uniform', 'algorithm': 'brute'}
# 0.611 (+/-0.064) for {'n_neighbors': 20, 'metric': 'euclidean', 'weights': 'distance', 'algorithm': 'brute'}
# 0.602 (+/-0.056) for {'n_neighbors': 5, 'metric': 'manhattan', 'weights': 'uniform', 'algorithm': 'brute'}
# 0.598 (+/-0.062) for {'n_neighbors': 5, 'metric': 'manhattan', 'weights': 'distance', 'algorithm': 'brute'}
# 0.594 (+/-0.080) for {'n_neighbors': 10, 'metric': 'manhattan', 'weights': 'uniform', 'algorithm': 'brute'}
# 0.610 (+/-0.094) for {'n_neighbors': 10, 'metric': 'manhattan', 'weights': 'distance', 'algorithm': 'brute'}
# 0.621 (+/-0.080) for {'n_neighbors': 15, 'metric': 'manhattan', 'weights': 'uniform', 'algorithm': 'brute'}
# 0.618 (+/-0.073) for {'n_neighbors': 15, 'metric': 'manhattan', 'weights': 'distance', 'algorithm': 'brute'}
# 0.613 (+/-0.085) for {'n_neighbors': 20, 'metric': 'manhattan', 'weights': 'uniform', 'algorithm': 'brute'}
# 0.619 (+/-0.057) for {'n_neighbors': 20, 'metric': 'manhattan', 'weights': 'distance', 'algorithm': 'brute'}
# 0.587 (+/-0.085) for {'n_neighbors': 5, 'metric': 'chebyshev', 'weights': 'uniform', 'algorithm': 'brute'}
# 0.603 (+/-0.058) for {'n_neighbors': 5, 'metric': 'chebyshev', 'weights': 'distance', 'algorithm': 'brute'}
# 0.581 (+/-0.084) for {'n_neighbors': 10, 'metric': 'chebyshev', 'weights': 'uniform', 'algorithm': 'brute'}
# 0.601 (+/-0.078) for {'n_neighbors': 10, 'metric': 'chebyshev', 'weights': 'distance', 'algorithm': 'brute'}
# 0.608 (+/-0.055) for {'n_neighbors': 15, 'metric': 'chebyshev', 'weights': 'uniform', 'algorithm': 'brute'}
# 0.607 (+/-0.072) for {'n_neighbors': 15, 'metric': 'chebyshev', 'weights': 'distance', 'algorithm': 'brute'}
# 0.606 (+/-0.069) for {'n_neighbors': 20, 'metric': 'chebyshev', 'weights': 'uniform', 'algorithm': 'brute'}
# 0.611 (+/-0.056) for {'n_neighbors': 20, 'metric': 'chebyshev', 'weights': 'distance', 'algorithm': 'brute'}
# 0.597 (+/-0.089) for {'n_neighbors': 5, 'metric': 'minkowski', 'weights': 'uniform', 'algorithm': 'brute'}
# 0.596 (+/-0.056) for {'n_neighbors': 5, 'metric': 'minkowski', 'weights': 'distance', 'algorithm': 'brute'}
# 0.584 (+/-0.082) for {'n_neighbors': 10, 'metric': 'minkowski', 'weights': 'uniform', 'algorithm': 'brute'}
# 0.606 (+/-0.082) for {'n_neighbors': 10, 'metric': 'minkowski', 'weights': 'distance', 'algorithm': 'brute'}
# 0.613 (+/-0.064) for {'n_neighbors': 15, 'metric': 'minkowski', 'weights': 'uniform', 'algorithm': 'brute'}
# 0.614 (+/-0.063) for {'n_neighbors': 15, 'metric': 'minkowski', 'weights': 'distance', 'algorithm': 'brute'}
# 0.610 (+/-0.080) for {'n_neighbors': 20, 'metric': 'minkowski', 'weights': 'uniform', 'algorithm': 'brute'}
# 0.611 (+/-0.064) for {'n_neighbors': 20, 'metric': 'minkowski', 'weights': 'distance', 'algorithm': 'brute'}
#
# Best Score:
#
#
# Best Params:
#
# 0.621111111111
# {'n_neighbors': 15, 'metric': 'manhattan', 'weights': 'uniform', 'algorithm': 'auto'}
#
# Classification Report:
#
#              precision    recall  f1-score   support
#
#           1       0.00      0.00      0.00        14
#           2       0.00      0.00      0.00        13
#           3       0.00      0.00      0.00        86
#           4       0.41      0.22      0.28       625
#           5       0.67      0.87      0.76      1362
#
# avg / total       0.56      0.63      0.57      2100
#
#
# >> End Processing KNeighborsClassifier

# %%
print xx.shape
# Out:
# (3000, 100)

# %%
print yy.ravel()
# Out:
# [5 3 5 ..., 5 5 5]
